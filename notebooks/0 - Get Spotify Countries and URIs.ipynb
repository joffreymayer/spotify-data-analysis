# %%
import pandas as pd

# %%
test = pd.read_csv(
    "/Users/jomaye/Documents/Programming/04-DS-repos/Python/spotify-api/datasets/SpotifyTopSongsByCountry - May 2020.csv", 
    sep=',' # Im CSV-File waren die Spalten via ","-Taste separiert, deshalb diese option zwingend anzugeben ist (ansonsten Error!)
)

# %%
test
# Out:
#       Country Continent  Rank                            Title  \
# 0      Global    Global     1  Rain On Me (with Ariana Grande)
# 1      Global    Global     2                  Blinding Lights
# 2      Global    Global     3     ROCKSTAR (feat. Roddy Ricch)
# 3      Global    Global     4            Roses - Imanbek Remix
# 4      Global    Global     5                     Toosie Slide
# ...       ...       ...   ...                              ...
# 3145  Vietnam      Asia    46                       ĐÃ TỪNG LÀ
# 3146  Vietnam      Asia    47                Mượn Rượu Tỏ Tình
# 3147  Vietnam      Asia    48                     Ngày Tận Thế
# 3148  Vietnam      Asia    49                     Đi Đu Đưa Đi
# 3149  Vietnam      Asia    50                  Blinding Lights
#
#                          Artists                            Album  Explicit  \
# 0       Lady Gaga, Ariana Grande  Rain On Me (with Ariana Grande)         0
# ...

# %%
unique_country_names = test['Country'].unique()
unique_continent_names = test['Continent'].unique()

# %%
unique_country_names
# Out:
# array(['Global', 'Argentina', 'Australia', 'Austria', 'Belgium',
#        'Bolivia', 'Brazil', 'Bulgaria', 'Canada', 'Chile', 'Colombia',
#        'Costa Rica', 'Czech Republic', 'Denmark', 'Dominican Republic',
#        'Ecuador', 'El Salvador', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Guatemala', 'Honduras', 'Hong Kong',
#        'Hungary', 'Iceland', 'India', 'Indonesia', 'Ireland', 'Israel',
#        'Italy', 'Japan', 'Latvia', 'Lithuania', 'Luxembourg', 'Malaysia',
#        'Malta', 'Mexico', 'Netherlands', 'New Zealand', 'Nicaragua',
#        'Norway', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland',
#        'Portugal', 'Romania', 'Singapore', 'Slovakia', 'South Africa',
#        'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey',
#        'United Kingdom', 'United States', 'Uruguay', 'Vietnam'],
#       dtype=object)

# %%
unique_continent_names
# Out:
# array(['Global', 'South America', 'Australia', 'Europe', 'North America',
#        'Asia', 'Africa'], dtype=object)

# %%
for el in unique_country_names:
    print(el+",")
    #print(unique_country_names[el.index].replace("'", ""))
# Out:
# Global,
# Argentina,
# Australia,
# Austria,
# Belgium,
# Bolivia,
# Brazil,
# Bulgaria,
# Canada,
# Chile,
# Colombia,
# Costa Rica,
# Czech Republic,
# Denmark,
# Dominican Republic,
# Ecuador,
# El Salvador,
# Estonia,
# Finland,
# France,
# Germany,
# Greece,
# Guatemala,
# Honduras,
# Hong Kong,
# Hungary,
# Iceland,
# India,
# Indonesia,
# Ireland,
# Israel,
# Italy,
# Japan,
# Latvia,
# Lithuania,
# Luxembourg,
# Malaysia,
# Malta,
# Mexico,
# Netherlands,
# New Zealand,
# Nicaragua,
# Norway,
# Panama,
# Paraguay,
# Peru,
# Philippines,
# Poland,
# Portugal,
# Romania,
# Singapore,
# Slovakia,
# South Africa,
# Spain,
# Sweden,
# Switzerland,
# Taiwan,
# Thailand,
# Turkey,
# United Kingdom,
# United States,
# Uruguay,
# Vietnam,

# %%
for el in unique_continent_names:
    print(el+",")
# Out:
# Global,
# South America,
# Australia,
# Europe,
# North America,
# Asia,
# Africa,

# %%
# next, we need to extract the URIs by using all of those extracted countries' names. 
# To get the URIs, we simply go onto the following website: https://open.spotify.com/search
# Then - in the search-bar - simply paste in: "Top 50 - 'COUNTRY_NAME'"

# %%
test[test['Country'] == 'India']
# Out:
#      Country Continent  Rank  \
# 1350   India      Asia     1
# 1351   India      Asia     2
# 1352   India      Asia     3
# 1353   India      Asia     4
# 1354   India      Asia     5
# 1355   India      Asia     6
# 1356   India      Asia     7
# 1357   India      Asia     8
# 1358   India      Asia     9
# 1359   India      Asia    10
# 1360   India      Asia    11
# 1361   India      Asia    12
# 1362   India      Asia    13
# 1363   India      Asia    14
# 1364   India      Asia    15
# 1365   India      Asia    16
# 1366   India      Asia    17
# 1367   India      Asia    18
# 1368   India      Asia    19
# 1369   India      Asia    20
# 1370   India      Asia    21
# 1371   India      Asia    22
# 1372   India      Asia    23
# 1373   India      Asia    24
# 1374   India      Asia    25
# 1375   India      Asia    26
# 1376   India      Asia    27
# 1377   India      Asia    28
# 1378   India      Asia    29
# 1379   India      Asia    30
# 1380   India      Asia    31
# ...
